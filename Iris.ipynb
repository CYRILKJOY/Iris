# %% [markdown]
# # Importing Data Set

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("E:\\Projects\\Iris\\Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.pairplot(data,hue='Species')
plt.show()

# %%
plt.figure(figsize=(15,10))
data.groupby('Species')['SepalLengthCm'].plot()
plt.legend()
plt.title('Distribution of Species v/s Sepal Length',size=20)
plt.show()

# %%
plt.figure(figsize=(15,10))
data.groupby('Species')['SepalWidthCm'].plot()
plt.title('Distribution of Species v/s SepalWidthCm',size=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
data.groupby('Species')['PetalLengthCm'].plot()
plt.title('Distribution of Species v/s PetalLengthCm',size=20)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,10))
data.groupby('Species')['PetalWidthCm'].plot()
plt.legend()
plt.title('Distribution of Species v/s PetalWidthCm',size=20)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species',y='PetalLengthCm',data=data)
plt.subplot(2,2,2)
sns.violinplot(x='Species',y='PetalWidthCm',data=data)
plt.subplot(2,2,3)
sns.violinplot(x='Species',y='SepalLengthCm',data=data)
plt.subplot(2,2,4)
sns.violinplot(x='Species',y='SepalWidthCm',data=data)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.catplot(x='SepalLengthCm',y='SepalWidthCm',data=data,hue='Species')
plt.title('Distribution of Sepal Length and Sepal Width',size=20)
plt.xticks(rotation='90')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.catplot(x='PetalLengthCm',y='PetalWidthCm',data=data,hue='Species')
plt.title('Distribution of PetalLengthCm and petal Width' ,size=20)
plt.xticks(rotation='90')
plt.show()

# %% [markdown]
# # Prediction

# %%
y=data['Species']

# %%
X=data.drop(['Id','Species'],axis=1)

# %%
X.shape
# Out:
# (150, 4)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,stratify=y,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
K=KNeighborsClassifier(n_neighbors=5)
K.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
K.score(X_test,y_test)
# Out:
# 0.9777777777777777
